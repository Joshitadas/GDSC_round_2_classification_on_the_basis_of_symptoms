# %%
import numpy as np
import matplotlib
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# #Data cleaning

# %%
#reading the data

# %%
df = pd.read_csv("C:/Users/joshi/Downloads/Train.csv")

# print(df.to_string())
print(pd.options.display.max_rows) 

column_headers = list(df.columns.values)
print("The Column Header :", column_headers)
# Out:
# 60
# The Column Header : ['ID', 'Cough', 'Shortness of breath', 'Fatigue', 'body aches', 'Headache', 'Loss of taste', 'family history', 'Loss of smell', 'Nausea', 'Diarrhea', 'Misc Symptom 1', 'Congestion', 'Sore throat', 'Region', 'Misc Symptom 2', 'Misc Symptom 3', 'Misc Symptom 4', 'Misc Symptom 5', 'Misc Symptom 6', 'Misc Symptom 7', 'Pre-existing symptoms', 'Age', 'Variant']

# %%
print(df.head())
# Out:
#     ID  Cough  Shortness of breath  Fatigue  body aches  Headache  \
# 0  309      2                    3        2           0       2.0
# 1  486      2                    2        1           0       0.0
# 2  199      3                    3        3           0       2.0
# 3  495      2                    1        3           0       2.0
# 4  401      3                    2        2           0       0.0
#
#    Loss of taste family history  Loss of smell  Nausea  ...    Region  \
# 0              0            Yes              2     0.0  ...  Americas
# 1              0            Yes              1     0.0  ...    Europe
# 2              0            Yes              2     0.0  ...    Europe
# 3              0            Yes              0     0.0  ...    Europe
# 4              0            Yes              2     0.0  ...  Americas
#
#    Misc Symptom 2  Misc Symptom 3  Misc Symptom 4 Misc Symptom 5  \
# 0               0               1               2              0
# ...

# %%
df
# Out:
#       ID  Cough  Shortness of breath  Fatigue  body aches  Headache  \
# 0    309      2                    3        2           0       2.0
# 1    486      2                    2        1           0       0.0
# 2    199      3                    3        3           0       2.0
# 3    495      2                    1        3           0       2.0
# 4    401      3                    2        2           0       0.0
# ..   ...    ...                  ...      ...         ...       ...
# 407  355      2                    2        2           0       0.0
# 408  231      3                    2        3           0       2.0
# 409   22      3                    3        2           0       0.0
# 410  192      1                    1        1           0       2.0
# 411  233      2                    2        3           0       0.0
#
#      Loss of taste family history  Loss of smell  Nausea  ...  \
# 0                0            Yes              2     0.0  ...
# ...

# %%
# dropping invalid symptoms
df.drop(labels=["family history"], inplace=True,axis=1)
df.drop(labels=["Region"], inplace=True,axis=1)
df.drop(labels=["Pre-existing symptoms"], inplace=True,axis=1)
df.drop(labels=["body aches"], inplace=True,axis=1)
df.drop(labels=["Headache"], inplace=True,axis=1)
df.drop(labels=["Loss of taste"], inplace=True,axis=1)

# %%
df.head()
# Out:
#     ID  Cough  Shortness of breath  Fatigue  Loss of smell  Nausea  Diarrhea  \
# 0  309      2                    3        2              2     0.0       0.0
# 1  486      2                    2        1              1     0.0       2.0
# 2  199      3                    3        3              2     0.0       0.0
# 3  495      2                    1        3              0     0.0       3.0
# 4  401      3                    2        2              2     0.0       0.0
#
#    Misc Symptom 1  Congestion  Sore throat  Misc Symptom 2  Misc Symptom 3  \
# 0             2.0           2            3               0               1
# 1             1.0           0            0               1               0
# 2             2.0           2            3               3               0
# 3             NaN           0            0               0               0
# 4             1.0           0            2               0               0
#
# ...

# %%
plt.bar(df['Cough'], df['Variant'])
plt.show()

# %%
plt.bar(df['Shortness of breath'], df['Variant'])
plt.show()

# %%
plt.bar(df['Fatigue'], df['Variant'])

plt.xlabel('Fatigue')
plt.ylabel('Variant')
plt.show()

# %%
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'ID'}>,
#         <AxesSubplot:title={'center':'Cough'}>,
#         <AxesSubplot:title={'center':'Shortness of breath'}>,
#         <AxesSubplot:title={'center':'Fatigue'}>],
#        [<AxesSubplot:title={'center':'Loss of smell'}>,
#         <AxesSubplot:title={'center':'Nausea'}>,
#         <AxesSubplot:title={'center':'Diarrhea'}>,
#         <AxesSubplot:title={'center':'Misc Symptom 1'}>],
#        [<AxesSubplot:title={'center':'Congestion'}>,
#         <AxesSubplot:title={'center':'Sore throat'}>,
#         <AxesSubplot:title={'center':'Misc Symptom 2'}>,
#         <AxesSubplot:title={'center':'Misc Symptom 3'}>],
#        [<AxesSubplot:title={'center':'Misc Symptom 4'}>,
#         <AxesSubplot:title={'center':'Misc Symptom 5'}>,
#         <AxesSubplot:title={'center':'Misc Symptom 6'}>,
#         <AxesSubplot:title={'center':'Misc Symptom 7'}>],
#        [<AxesSubplot:title={'center':'Age'}>, <AxesSubplot:>,
# ...

# %%
import seaborn as sns
sns.boxplot(df['Nausea'])
# Out:
# C:\Users\joshi\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Nausea'>

# %%
Q1 = np.percentile(df['Cough'], 25,
                   interpolation = 'midpoint')
 
Q3 = np.percentile(df['Cough'], 75,
                   interpolation = 'midpoint')
IQR = Q3 - Q1

# %%
df.fillna(0)
# Out:
#       ID  Cough  Shortness of breath  Fatigue  Loss of smell  Nausea  \
# 0    309      2                    3        2              2     0.0
# 1    486      2                    2        1              1     0.0
# 2    199      3                    3        3              2     0.0
# 3    495      2                    1        3              0     0.0
# 4    401      3                    2        2              2     0.0
# ..   ...    ...                  ...      ...            ...     ...
# 407  355      2                    2        2              0     0.0
# 408  231      3                    2        3              2     0.0
# 409   22      3                    3        2              0     0.0
# 410  192      1                    1        1              2     0.0
# 411  233      2                    2        3              0     0.0
#
#      Diarrhea  Misc Symptom 1  Congestion  Sore throat  Misc Symptom 2  \
# ...

# %%
# models testing

# %%
import sklearn
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
x = df.drop('Variant', axis=1)
y = df['Variant']

x=x.fillna(0)
y = y.fillna(0)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.20)

# %%
svclassifier = SVC(kernel='linear')
svclassifier.fit(x_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred = svclassifier.predict(x_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[35  0  0  0  0  0]
#  [ 0 20  0  2  0  1]
#  [ 0  0  6  1  0  0]
#  [ 0  1  2  5  0  1]
#  [ 0  0  0  0  7  0]
#  [ 0  0  0  0  0  2]]
#               precision    recall  f1-score   support
#
#    Variant 1       1.00      1.00      1.00        35
#    Variant 2       0.95      0.87      0.91        23
#    Variant 3       0.75      0.86      0.80         7
#    Variant 4       0.62      0.56      0.59         9
#    Variant 5       1.00      1.00      1.00         7
#    Variant 6       0.50      1.00      0.67         2
#
#     accuracy                           0.90        83
#    macro avg       0.80      0.88      0.83        83
# weighted avg       0.91      0.90      0.91        83

# %%
data = pd.read_csv("C:/Users/joshi/Downloads/Test.csv")

# print(df.to_string())
print(pd.options.display.max_rows) 

column_headers = list(data.columns.values)
# Out:
# 60

# %%
# dropping invalid symptoms
data.drop(labels=["family history"], inplace=True,axis=1)
data.drop(labels=["Region"], inplace=True,axis=1)
data.drop(labels=["Pre-existing symptoms"], inplace=True,axis=1)
data.drop(labels=["body aches"], inplace=True,axis=1)
data.drop(labels=["Headache"], inplace=True,axis=1)
data.drop(labels=["Loss of taste"], inplace=True,axis=1)
data
# Out:
#       ID  Cough  Shortness of breath  Fatigue  Loss of smell  Nausea  \
# 0     95      1                    2        2              0       1
# 1    502      3                    2        2              1       0
# 2    203      2                    3        1              1       0
# 3    290      2                    2        2              1       0
# 4    479      1                    2        2              0       0
# ..   ...    ...                  ...      ...            ...     ...
# 172  398      2                    1        3              3       0
# 173  117      2                    2        1              0       0
# 174   74      3                    2        2              1       0
# 175  299      2                    1        2              1       0
# 176   94      3                    2        1              0       0
#
#      Diarrhea  Misc Symptom 1  Congestion  Sore throat  Misc Symptom 2  \
# ...

# %%
data.fillna(0)
# Out:
#       ID  Cough  Shortness of breath  Fatigue  Loss of smell  Nausea  \
# 0     95      1                    2        2              0       1
# 1    502      3                    2        2              1       0
# 2    203      2                    3        1              1       0
# 3    290      2                    2        2              1       0
# 4    479      1                    2        2              0       0
# ..   ...    ...                  ...      ...            ...     ...
# 172  398      2                    1        3              3       0
# 173  117      2                    2        1              0       0
# 174   74      3                    2        2              1       0
# 175  299      2                    1        2              1       0
# 176   94      3                    2        1              0       0
#
#      Diarrhea  Misc Symptom 1  Congestion  Sore throat  Misc Symptom 2  \
# ...

# %%
# x_test = data.drop('Variant', axis=1)
# y_test = data['Variant']
# x_test=x_test.fillna(0)
# y_test = y_test.fillna(0)
# x

# %%
y_pred = svclassifier.predict(x_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[35  0  0  0  0  0]
#  [ 0 20  0  2  0  1]
#  [ 0  0  6  1  0  0]
#  [ 0  1  2  5  0  1]
#  [ 0  0  0  0  7  0]
#  [ 0  0  0  0  0  2]]
#               precision    recall  f1-score   support
#
#    Variant 1       1.00      1.00      1.00        35
#    Variant 2       0.95      0.87      0.91        23
#    Variant 3       0.75      0.86      0.80         7
#    Variant 4       0.62      0.56      0.59         9
#    Variant 5       1.00      1.00      1.00         7
#    Variant 6       0.50      1.00      0.67         2
#
#     accuracy                           0.90        83
#    macro avg       0.80      0.88      0.83        83
# weighted avg       0.91      0.90      0.91        83

# %%
svclassifier = SVC(kernel='sigmoid')
svclassifier.fit(x_train, y_train)
# Out:
# SVC(kernel='sigmoid')

# %%
y_pred = svclassifier.predict(x_test)

# %%
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[20 15  0  0  0  0]
#  [14  9  0  0  0  0]
#  [ 1  6  0  0  0  0]
#  [ 5  4  0  0  0  0]
#  [ 5  2  0  0  0  0]
#  [ 0  2  0  0  0  0]]
#               precision    recall  f1-score   support
#
#    Variant 1       0.44      0.57      0.50        35
#    Variant 2       0.24      0.39      0.30        23
#    Variant 3       0.00      0.00      0.00         7
#    Variant 4       0.00      0.00      0.00         9
#    Variant 5       0.00      0.00      0.00         7
#    Variant 6       0.00      0.00      0.00         2
#
#     accuracy                           0.35        83
#    macro avg       0.11      0.16      0.13        83
# weighted avg       0.25      0.35      0.29        83
# C:\Users\joshi\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import BaggingClassifier
from sklearn.datasets import make_classification

# %%
model_params={
    'svm': {
        'model': svm.SVC(gamma='auto', probability= True),
        'params':{
            'svc__C':[1,10,100,1000],
            'svc__kernel': ['rbf', 'linear']
        }
    },
    'random_forest':{
        'model': RandomForestClassifier(),
        'params':{
            'randomforestclassifier__n_estimators':[1,5,10]
        }
    },
    'logistic_regression':{
        'model': LogisticRegression(solver = 'liblinear', multi_class ='auto'),
        'params':{
            'logisticregression__C': [1,5,10]
        }
        
    }
}

# %%
scores =[]
best_estimators={}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(),mp['model'])
    clf= GridSearchCV(pipe, mp['params'], cv =5, return_train_score = False)
    clf.fit(x_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo]= clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model', 'best_score', 'best_params'])
df
# print(best_estimators)
# Out:
#                  model  best_score  \
# 0                  svm    0.896643
# 1        random_forest    0.899627
# 2  logistic_regression    0.902704
#
#                                     best_params
# 0           {'svc__C': 1, 'svc__kernel': 'rbf'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                  {'logisticregression__C': 5}

# %%
best_estimators['svm'].score(x_test, y_test)
# Out:
# 0.9036144578313253

# %%
best_estimators['random_forest'].score(x_test, y_test)
# Out:
# 0.8795180722891566

# %%
best_estimators['logistic_regression'].score(x_test, y_test)
# Out:
# 0.891566265060241

# %%
best_clf = best_estimators['logistic_regression']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,best_clf.predict(x_test))
cm
# Out:
# array([[35,  0,  0,  0,  0,  0],
#        [ 0, 21,  1,  1,  0,  0],
#        [ 0,  0,  6,  1,  0,  0],
#        [ 0,  1,  4,  4,  0,  0],
#        [ 0,  0,  0,  0,  7,  0],
#        [ 0,  1,  0,  0,  0,  1]], dtype=int64)

# %%
import seaborn as sn
plt.figure(figsize =(10,7))
sn.heatmap(cm, annot = True)
plt.xlabel('Prediction')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')

# %%
import joblib
joblib.dump(best_clf, 'saved_model_gdsc.pkl')
# Out:
# ['saved_model_gdsc.pkl']

# %%
y=best_clf.predict(data)
y
# Out:
# array(['Variant 5', 'Variant 1', 'Variant 1', 'Variant 1', 'Variant 3',
#        'Variant 1', 'Variant 1', 'Variant 5', 'Variant 5', 'Variant 3',
#        'Variant 6', 'Variant 3', 'Variant 6', 'Variant 2', 'Variant 2',
#        'Variant 1', 'Variant 2', 'Variant 1', 'Variant 6', 'Variant 2',
#        'Variant 4', 'Variant 1', 'Variant 5', 'Variant 3', 'Variant 5',
#        'Variant 1', 'Variant 2', 'Variant 2', 'Variant 1', 'Variant 6',
#        'Variant 1', 'Variant 1', 'Variant 1', 'Variant 4', 'Variant 1',
#        'Variant 3', 'Variant 6', 'Variant 1', 'Variant 2', 'Variant 4',
#        'Variant 3', 'Variant 2', 'Variant 2', 'Variant 2', 'Variant 2',
#        'Variant 3', 'Variant 5', 'Variant 5', 'Variant 6', 'Variant 2',
#        'Variant 1', 'Variant 2', 'Variant 3', 'Variant 5', 'Variant 3',
#        'Variant 3', 'Variant 1', 'Variant 1', 'Variant 2', 'Variant 5',
#        'Variant 5', 'Variant 1', 'Variant 5', 'Variant 2', 'Variant 1',
# ...

# %%
id = data[data.columns[0]].values.tolist()
id
# Out:
# [95,
#  502,
#  203,
#  290,
#  479,
#  478,
#  167,
#  536,
#  456,
#  147,
#  442,
#  455,
#  326,
#  357,
#  513,
#  25,
#  470,
#  537,
#  310,
#  101,
#  344,
#  307,
#  19,
#  38,
#  39,
#  86,
#  394,
#  303,
#  260,
#  312,
#  180,
#  373,
#  130,
#  113,
#  26,
#  319,
#  557,
#  588,
#  228,
#  447,
#  90,
#  168,
#  250,
#  207,
#  213,
#  317,
#  21,
#  234,
#  407,
#  114,
#  327,
#  581,
#  348,
#  271,
#  8,
#  350,
#  492,
#  510,
#  543,
#  58,
#  146,
#  540,
#  534,
#  512,
#  16,
#  522,
#  368,
#  31,
#  436,
#  343,
#  416,
#  77,
#  134,
#  49,
#  107,
#  483,
#  451,
#  329,
#  565,
#  514,
#  551,
#  170,
#  399,
#  210,
#  111,
#  482,
#  518,
#  263,
#  142,
#  542,
#  181,
#  586,
#  505,
#  270,
#  393,
#  389,
#  476,
#  232,
#  64,
#  248,
#  98,
#  128,
#  576,
#  585,
#  547,
#  239,
#  4,
#  11,
#  308,
#  89,
#  288,
#  531,
#  362,
#  477,
#  500,
#  571,
#  342,
#  463,
#  419,
#  324,
#  425,
#  253,
#  238,
#  466,
#  47,
#  99,
#  493,
#  230,
# ...

# %%
id_arr=np.array(id)
id_arr
# Out:
# array([ 95, 502, 203, 290, 479, 478, 167, 536, 456, 147, 442, 455, 326,
#        357, 513,  25, 470, 537, 310, 101, 344, 307,  19,  38,  39,  86,
#        394, 303, 260, 312, 180, 373, 130, 113,  26, 319, 557, 588, 228,
#        447,  90, 168, 250, 207, 213, 317,  21, 234, 407, 114, 327, 581,
#        348, 271,   8, 350, 492, 510, 543,  58, 146, 540, 534, 512,  16,
#        522, 368,  31, 436, 343, 416,  77, 134,  49, 107, 483, 451, 329,
#        565, 514, 551, 170, 399, 210, 111, 482, 518, 263, 142, 542, 181,
#        586, 505, 270, 393, 389, 476, 232,  64, 248,  98, 128, 576, 585,
#        547, 239,   4,  11, 308,  89, 288, 531, 362, 477, 500, 571, 342,
#        463, 419, 324, 425, 253, 238, 466,  47,  99, 493, 230, 450, 217,
#        121,  51, 136, 116, 439, 527,  17, 208, 465, 508,  71, 422, 559,
#        446, 382, 275, 127,   3, 277, 126, 564, 242, 151,   0,  50, 490,
#        539, 189, 268,  14, 494, 184, 420, 424, 509, 183, 491,  45, 339,
# ...

# %%
len(id_arr)
# Out:
# 177

# %%
len(y)
# Out:
# 177

# %%
final = pd.DataFrame({'ID' : id_arr,
                                'Variant' : y }, 
                                columns=['ID','Variant'])
final
# Out:
#       ID    Variant
# 0     95  Variant 5
# 1    502  Variant 1
# 2    203  Variant 1
# 3    290  Variant 1
# 4    479  Variant 3
# ..   ...        ...
# 172  398  Variant 1
# 173  117  Variant 3
# 174   74  Variant 2
# 175  299  Variant 2
# 176   94  Variant 1
#
# [177 rows x 2 columns]

# %%
final.to_csv("C:/Users/joshi/Downloads/Final3.csv", index =False)
